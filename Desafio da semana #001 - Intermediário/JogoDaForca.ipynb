# %%
import random

with open("cidadesBrasil.txt", "r", encoding="utf-8") as file: 
    allText = file.read() 
    words = list(map(str, allText.split("\n"))) # Dividindo o texto por quebra de linha
    

def escolher_palavra():
    return random.choice(words).upper()

def exibir_palavra(palavra, letras_corretas):
    # Mostra a palavra com as letras adivinhadas preenchidas e os espaços em branco para as letras não adivinhadas
    exibicao = ""
    for letra in palavra:
        if letra in letras_corretas:
            exibicao += letra + " "
        else:
            exibicao += "_ "
    return exibicao.strip()

def jogar_forca():
    palavra = escolher_palavra()
    letras_corretas = set()
    tentativas = 6

    print("==================================================")
    print("\tBEM-VINDO AO JOGO DA FORCA!")
    print("Tente adivinhar a palavra. Você tem 6 tentativas.")
    print("==================================================")
    print("Dica: A palavra é uma cidade brasileira\n")

    print(exibir_palavra(palavra, letras_corretas))

    while tentativas > 0:
        palpite = input("\nDigite uma letra ou a palavra completa: ").upper()

        if len(palpite) == 1:  # Se o palpite for uma letra
            if palpite in palavra:
                letras_corretas.add(palpite)
                print("Letra correta!")
            else:
                tentativas -= 1
                print("Letra incorreta. Você tem {} tentativas restantes.".format(tentativas))
        elif len(palpite) == len(palavra.replace(" ", "")) and palpite.isalpha():  # Se o palpite for a palavra completa
            if palpite.upper() == palavra.replace(" ", "").upper():
                print("\n=================================================================")
                print("\nPARABÉNS! Você adivinhou a palavra corretamente: '{}'".format(palavra))
                break
            else:
                tentativas -= 1
                print("Palavra incorreta. Você tem {} tentativas restantes.".format(tentativas))
        else:
            print("Por favor, insira apenas uma letra ou a palavra completa.")

        print(exibir_palavra(palavra, letras_corretas))

    if tentativas == 0:
        print("\n=============================================================")
        print("\nVOCÊ PERDEU! A palavra correta era '{}'.".format(palavra))
        print("Mais sorte na próxima vez! ;)")

jogar_forca()
# Out:
# ==================================================
# 	BEM-VINDO AO JOGO DA FORCA!
# Tente adivinhar a palavra. Você tem 6 tentativas.
# ==================================================
# Dica: A palavra é uma cidade brasileira
#
# _ _ _ _ _ _ _ _ _
#
# Digite uma letra ou a palavra completa: a
# Letra correta!
# _ _ _ _ _ _ _ _ A
#
# Digite uma letra ou a palavra completa: e
# Letra incorreta. Você tem 5 tentativas restantes.
# _ _ _ _ _ _ _ _ A
#
# Digite uma letra ou a palavra completa: i
# Letra correta!
# _ _ _ _ _ _ _ I A
#
# Digite uma letra ou a palavra completa: o
# Letra correta!
# _ O _ _ _ _ _ I A
#
# Digite uma letra ou a palavra completa: m
# Letra incorreta. Você tem 4 tentativas restantes.
# _ O _ _ _ _ _ I A
#
# Digite uma letra ou a palavra completa: n
# Letra correta!
# _ O N _ _ _ _ I A
#
# Digite uma letra ou a palavra completa: p
# Letra incorreta. Você tem 3 tentativas restantes.
# _ O N _ _ _ _ I A
#
# Digite uma letra ou a palavra completa: t
# Letra incorreta. Você tem 2 tentativas restantes.
# _ O N _ _ _ _ I A
#
# Digite uma letra ou a palavra completa: j
# Letra incorreta. Você tem 1 tentativas restantes.
# _ O N _ _ _ _ I A
#
# Digite uma letra ou a palavra completa: u
# Letra incorreta. Você tem 0 tentativas restantes.
# _ O N _ _ _ _ I A
#
# =============================================================
#
# VOCÊ PERDEU! A palavra correta era 'CONCÓRDIA'.
# Mais sorte na próxima vez! ;)
